# %%
# https://www.dataquest.io/blog/python-api-tutorial/

# Response codes and their meanings
# 200: Everything went okay, and the result has been returned (if any).
# 301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# 400: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# 401: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# 403: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.
# 404: The resource you tried to access wasn’t found on the server.
# 503: The server is not ready to handle the request.

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from tqdm import tqdm
import time
from xml.etree import ElementTree as ET
import lxml

# %%
id_list = []

def scrape_bgg_game_ids(page_num=1):
    global id_list
    
    page_num = str(page_num)
    
    # Define the list
    
    # Define search parameters
    search_url = 'https://boardgamegeek.com/sitemap_geekitems_boardgame_page_{0}'.format(page_num)
    
    # Send a GET request to fetch the XML data
    response = requests.get(search_url)
    response.raise_for_status()  # Raise an exception if the request fails

    # Parse the XML data
    soup = BeautifulSoup(response.text,"lxml")

    # Get the main info on a game from start_url
    all_loc = soup.find_all("loc")

    seen = set() # Keep track of game_id and game_name tuple
    
    for loc in all_loc:        
        # Get the game's url
        url=loc.text
        # print(url)
                  
        # Extract game name using regular expression
        match = re.search(r'/(?P<digits>[0-9]+)/', url)
        if match:
            # Make sure the game id matches teh group called digits (defined in <digits> above)
            game_id = match.group('digits')
            # Remove the part of the url up to and including game_id
            game_name = url.replace(f'https://boardgamegeek.com/boardgame/{game_id}/','')
            # Replace hyphens with underscores
            game_name = game_name.replace('-','_')
            
            # Create a tuple, game_id game_name pair
            game = (game_id, game_name)
            
            # Only add the game to id_list if it hasn't been seen before
            if game not in seen:
                id_list.append(game)
                seen.add(game)
            
            print(f"Game Id: {game_id}, Game Name: {game_name}")
        else:
            print(f"No match found for game ID in the URL for game: {game_name}")
            
        
   # return id_list

# Usage
for i in tqdm(range(1,16)):
    game_ids = scrape_bgg_game_ids(i)
# Out:
#   0%|                                                                                           | 0/15 [00:00<?, ?it/s]C:\ProgramData\Anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
id_list
# Out:
# [('1', 'die_macher'),
#  ('2', 'dragonmaster'),
#  ('3', 'samurai'),
#  ('4', 'tal_der_konige'),
#  ('5', 'acquire'),
#  ('6', 'mare_mediterraneum'),
#  ('7', 'cathedral'),
#  ('8', 'lords_creation'),
#  ('9', 'el_caballero'),
#  ('10', 'elfenland'),
#  ('11', 'bohnanza'),
#  ('12', 'ra'),
#  ('13', 'catan'),
#  ('14', 'basari'),
#  ('15', 'cosmic_encounter'),
#  ('16', 'marracash'),
#  ('17', 'button_men'),
#  ('18', 'roborally'),
#  ('19', 'wacky_wacky_west'),
#  ('20', 'full_metal_planete'),
#  ('21', 'gateway_stars'),
#  ('22', 'magic_realm'),
#  ('23', 'divine_right'),
#  ('24', 'twilight_imperium'),
#  ('25', 'battlemist'),
#  ('26', 'age_renaissance'),
#  ('27', 'supremacy_game_superpowers'),
#  ('28', 'illuminati'),
#  ('29', 'terrain_vague'),
#  ('30', 'dark_tower'),
#  ('31', 'dark_world'),
#  ('32', 'buffalo_chess'),
#  ('34', 'arkham_horror'),
#  ('36', 'federation_empire'),
#  ('37', 'dragon_masters'),
#  ('38', 'runes'),
#  ('39', 'darkover'),
#  ('40', 'borderlands'),
#  ('41', 'cant_stop'),
#  ('42', 'tigris_euphrates'),
#  ('43', 'airlines'),
#  ('44', 'david_goliath'),
#  ('45', 'perudo'),
#  ('46', 'medici'),
#  ('47', 'chinatown'),
#  ('48', 'krieg_und_frieden'),
#  ('49', 'mamma_mia'),
#  ('50', 'lost_cities'),
#  ('51', 'ricochet_robots'),
#  ('52', 'mighty_empires'),
#  ('53', 'brauerei'),
#  ('54', 'tikal'),
#  ('55', 'sophies_world'),
#  ('57', 'schoko_co'),
#  ('58', 'kings_things'),
#  ('59', 'giganten'),
#  ('60', 'vinci'),
#  ('61', 'fossil'),
#  ('62', 'curse_mummys_tomb'),
#  ('63', 'samurai_game_politics_and_warfare_feudal_japan'),
#  ('64', 'joan_arc'),
#  ('65', 'garden_game'),
#  ('66', 'lowenherz'),
#  ('67', 'conquest'),
#  ('68', 'successors_firstsecond_edition'),
#  ('69', 'bollox'),
#  ('70', 'big_city'),
#  ('71', 'civilization'),
#  ('72', 'verrater'),
#  ('73', 'show_manager'),
#  ('74', 'apples_apples'),
#  ('75', 'falling'),
#  ('76', 'air_baron'),
#  ('77', 'eastfront'),
#  ('78', 'westfront_war_europe_1943_45'),
#  ('79', 'medfront_war_north_africa_1940_43'),
#  ('80', 'volgafront_east_eastfront_1942_43'),
#  ('81', 'eurofront_war_europe_1939_45'),
#  ('82', 'bobby_lee_civil_war_virginia_1861_1865'),
#  ('83', 'sam_grant_civil_war_west_1862_1864'),
#  ('84', 'rommel_desert'),
#  ('85', 'quebec_1759'),
#  ('87', 'victory_world_war_ii'),
#  ('88', 'torres'),
#  ('89', 'blue_vs_gray'),
#  ('90', 'star_wars_episode_1_clash_lightsabers'),
#  ('91', 'paths_glory'),
#  ('93', 'el_grande'),
#  ('94', 'union_pacific'),
#  ('95', 'igel_argern'),
#  ('96', 'broadsides_boarding_parties'),
#  ('97', 'conquest_empire'),
#  ('98', 'axis_allies'),
#  ('99', 'fortress_america'),
#  ('101', 'detroit_cleveland_grand_prix'),
#  ('102', 'klunker'),
#  ('103', 'titan'),
#  ('104', 'extrablatt'),
#  ('105', 'colossal_arena'),
#  ('106', 'mystery_rummy_jack_ripper'),
#  ('107', 'peaceful_resistance'),
#  ('108', 'tamsk'),
#  ('109', 'wettstreit_der_baumeister'),
#  ('110', 'auf_achse'),
#  ('111', 'rheinlander'),
#  ('112', 'condottiere'),
#  ('113', 'mit_list_und_tucke'),
#  ('114', 'ransom'),
#  ('115', 'im_boss'),
#  ('116', 'guillotine'),
#  ('117', 'ta_yu'),
#  ('118', 'modern_art'),
#  ('119', 'kingdoms'),
#  ('120', 'hoity_toity'),
#  ('121', 'dune'),
#  ('122', 'quo_vadis'),
#  ('123', 'green_thumb_cards'),
#  ('124', 'primordial_soup'),
#  ('125', 'money'),
#  ('126', 'really_nasty_horse_racing_game'),
#  ('127', 'princess_ryans_star_marines'),
#  ('128', 'take_it_easy'),
#  ('130', 'iron_dragon'),
#  ('132', 'caesar_cleopatra'),
#  ('133', 'frischfleisch'),
#  ('134', 'cape_horn'),
#  ('135', 'kontor'),
#  ('136', 'robin_hood'),
#  ('137', 'pass_bomb'),
#  ('139', 'hoax'),
#  ('140', 'pit'),
#  ('141', 'andromeda'),
#  ('142', 'vino'),
#  ('143', 'wortelboer'),
#  ('144', 'elfenwizards'),
#  ('145', 'metropolis'),
#  ('146', 'buy_low_sell_high'),
#  ('147', 'crude_oil_game'),
#  ('148', 'die_glucksritter'),
#  ('150', 'pitchcar'),
#  ('151', 'piratenbillard'),
#  ('152', 'mu_more'),
#  ('153', 'take_5'),
#  ('154', 'union_vs_central'),
#  ('155', 'was_sticht'),
#  ('156', 'wildlife_adventure'),
#  ('157', 'eurorails'),
#  ('158', 'elfengold'),
#  ('162', 'awful_green_things_outer_space'),
#  ('163', 'balderdash'),
#  ('164', 'i_kill_you_mister_spy'),
#  ('165', 'black_box'),
#  ('166', 'black_death'),
#  ('167', 'dicke_kartoffeln'),
#  ('168', 'empire_builder'),
#  ('169', 'en_garde'),
#  ('170', 'family_business'),
#  ('171', 'chess'),
#  ('172', 'sale'),
#  ('173', 'formula_de'),
#  ('174', 't_rex'),
#  ('175', 'what_heck'),
#  ('176', 'give_me_brain'),
#  ('177', 'advanced_civilization'),
#  ('178', 'mole_hill'),
#  ('179', 'nuba'),
#  ('180', 'pool_position'),
#  ('181', 'risk'),
#  ('182', 'knights_charlemagne'),
#  ('183', 'stonehenge'),
#  ('185', 'devil_bunny_needs_ham'),
#  ('186', 'split'),
#  ('188', 'go'),
#  ('189', 'die_siedler_von_nurnberg'),
#  ('190', 'dolce_vita'),
#  ('192', 'nicht_die_bohne'),
#  ('193', 'fill_or_bust'),
#  ('194', 'groo_game'),
#  ('195', 'nascar_champions'),
#  ('196', 'kremlin'),
#  ('197', 'hellrail_second_perdition'),
#  ('198', 'buried_treasure'),
#  ('199', 'manhattan'),
#  ('200', 'entdecker'),
#  ('201', 'rose_king'),
#  ('202', 'targui'),
#  ('203', 'skworms'),
#  ('204', 'stephensons_rocket'),
#  ('206', 'jalape_no'),
#  ('207', 'twitch'),
#  ('208', 'ex_hopp'),
#  ('210', 'don_pepe'),
#  ('211', 'times_remember'),
#  ('214', 'cafe_international'),
#  ('215', 'tichu'),
#  ('216', 'atlanteon'),
#  ('217', 'la_carte'),
#  ('218', 'high_bid'),
#  ('219', 'volle_hutte'),
#  ('220', 'high_society'),
#  ('221', 'ikusa'),
#  ('222', 'space_beans'),
#  ('223', 'expedition'),
#  ('224', 'history_world'),
#  ('225', 'icehouse'),
#  ('226', 'isi'),
#  ('227', 'knightmare_chess'),
#  ('228', 'lunch_money'),
#  ('229', 'king_elves'),
#  ('230', 'merchant_venus'),
#  ('231', 'geronimo'),
#  ('232', 'serenissima'),
#  ('234', 'hannibal_rome_vs_carthage'),
#  ('235', 'blackbeard'),
#  ('237', 'wooden_ships_iron_men'),
#  ('239', 'wagram_peace_vienna_5_6_july_1809'),
#  ('240', 'britannia'),
#  ('241', 'age_exploration'),
#  ('242', 'junta'),
#  ('243', 'advanced_squad_leader'),
#  ('244', 'circus_maximus'),
#  ('246', 'politika'),
#  ('247', 'gloria_picktoria'),
#  ('248', 'blood_royale'),
#  ('249', 'lifeboats'),
#  ('250', 'colonial_diplomacy'),
#  ('252', 'battle_borodino_napoleon_russia_1812'),
#  ('254', 'empires_arms'),
#  ('255', 'jena_auerstadt_battle_prussia_14_october_1806'),
#  ('256', 'mississippi_queen'),
#  ('257', 'kill_doctor_lucky'),
#  ('258', 'fluxx'),
#  ('259', 'atlantic_storm'),
#  ('260', 'starship_troopers_prepare_battle'),
#  ('261', 'olympia_2000_v_chr'),
#  ('263', 'manitou'),
#  ('264', 'enemy_sight'),
#  ('265', 'intrigue'),
#  ('267', 'tycoon'),
#  ('268', 'cheops'),
#  ('270', 'svea_rike'),
#  ('271', 'its_mine'),
#  ('272', 'downtown'),
#  ('273', 'africa_1880'),
#  ('274', 'guerilla'),
#  ('275', 'extinction'),
#  ('276', 'la_guerre_de_lempereur'),
#  ('277', 'res_publica'),
#  ('278', 'catan_card_game'),
#  ('279', 'very_clever_pipe_game'),
#  ('280', 'neue_spiele_im_alten_rom'),
#  ('281', 'ostindiska_kompaniet'),
#  ('282', 'vikingatid'),
#  ('283', 'advanced_third_reich'),
#  ('284', 'lords_sierra_madre_second_edition'),
#  ('285', 'monsters_ravage_america'),
#  ('286', 'machiavelli'),
#  ('287', 'bazaar'),
#  ('288', 'rossyia_1917'),
#  ('289', 'chariot_lords'),
#  ('290', 'gold_digger'),
#  ('291', 'courtisans_versailles'),
#  ('292', 'attacke'),
#  ('293', 'bamboleo'),
#  ('294', 'keydom'),
#  ('295', 'europa_1945_2030'),
#  ('296', 'medieval_merchant'),
#  ('297', 'stadens_nyckel'),
#  ('298', 'lang_lebe_der_konig'),
#  ('299', 'de_bellis_antiquitatis_quick_play_wargame_rules_ar'),
#  ('300', 'tutankhamen'),
#  ('301', 'campanile'),
#  ('302', 'forum_romanum'),
#  ('303', 'koalition'),
#  ('304', 'evergreen'),
#  ('305', 'der_fliegende_hollander'),
#  ('306', 'die_siedler_von_catan_historische_szenarien'),
#  ('307', 'candidate'),
#  ('308', 'santa_fe'),
#  ('309', 'arabana_ikibiti'),
#  ('310', 'wizards_quest'),
#  ('311', 'time_agent'),
#  ('312', 'landlord'),
#  ('313', 'big_boss'),
#  ('314', 'highlanders'),
#  ('315', 'bagh_chal'),
#  ('316', 'chase'),
#  ('317', 'mob'),
#  ('318', 'looney_leo'),
#  ('319', 'top_it'),
#  ('320', 'scrabble'),
#  ('321', 'mole_hole'),
#  ('322', 'tonga_bonga'),
#  ('323', 'anno_1452'),
#  ('324', 'ponte_vecchio'),
#  ('325', 'catan_seafarers'),
#  ('327', 'loopin_louie'),
#  ('328', 'damn_torpedoes'),
#  ('329', 'russian_front'),
#  ('330', 'block_mania'),
#  ('332', 'vernissage'),
#  ('333', 'waterworks'),
#  ('334', 'advance_boardwalk'),
#  ('335', 'breakthru'),
#  ('336', 'jumpin'),
#  ('337', 'circus_flohcati'),
#  ('338', 'bargain_hunter'),
#  ('339', 'quiddler'),
#  ('340', 'franks_zoo'),
#  ('342', 'hong_kong'),
#  ('343', 'twins'),
#  ('344', 'classic_art'),
#  ('345', 'prairie_railroads'),
#  ('347', 'fishy'),
#  ('348', 'merchants_middle_ages'),
#  ('349', 'halunken_spelunken'),
#  ('350', 'hattrick'),
#  ('352', 'trumpet'),
#  ('353', 'inkognito_card_game'),
#  ('354', 'stick_em'),
#  ('355', 'das_letzte_paradies'),
#  ('356', 'ab_die_post'),
#  ('357', 'excape'),
#  ('359', 'bucket_brigade'),
#  ('360', 'quests_round_table'),
#  ('361', 'hare_tortoise'),
#  ('362', 'elefantenparade'),
#  ('363', 'cat_blues'),
#  ('364', 'samarkand'),
#  ('365', 'tricks'),
#  ('366', 'viva_pamplona'),
#  ('367', 'overthrone'),
#  ('368', 'relationship_tightrope'),
#  ('369', '5ive_straight'),
#  ('370', 'el_grande_konig_intrigant'),
#  ('371', 'mystery_rummy_murders_rue_morgue'),
#  ('372', 'schotten_totten'),
#  ('373', 'wrott_swindlers'),
#  ('374', 'colorado_county'),
#  ('375', '6_billion'),
#  ('376', 'druidenwalzer'),
#  ('377', 'neighbors'),
#  ('378', 'lancashire_railways'),
#  ('379', 'express'),
#  ('380', 'polarity'),
#  ('381', 'x_pasch'),
#  ('382', 'heimlich_co'),
#  ('383', 'turf_horse_racing'),
#  ('384', 'turfmaster'),
#  ('386', 'pirateer'),
#  ('387', 'corruption'),
#  ('388', 'finale'),
#  ('389', 'die_mauer'),
#  ('391', 'ocean'),
#  ('392', 'brawl'),
#  ('393', 'dinosaurs_lost_world'),
#  ('394', 'kahuna'),
#  ('396', 'der_dreizehnte_holzwurm'),
#  ('397', 'diskwars'),
#  ('398', 'wildlife_safari'),
#  ('399', 'tom_clancys_politika'),
#  ('400', 'shanghai'),
#  ('401', 'gold_connection'),
#  ('403', 'elk_fest'),
#  ('404', 'worm'),
#  ('406', 'meteo'),
#  ('408', 'zoon'),
#  ('409', 'dschungel'),
#  ('410', 'draf'),
#  ('412', 'yukon_company'),
#  ('413', 'die_erben_von_hoax'),
#  ('414', 'around_world_80_days'),
#  ('415', 'espresso'),
#  ('416', 'z'),
#  ('417', 'edison_co'),
#  ('420', 'rail_baron'),
#  ('421', '1830_railways_robber_barons'),
#  ('422', '1835'),
#  ('423', '1856_railroading_upper_canada_1856'),
#  ('424', '1870_railroading_across_trans_mississippi_1870'),
#  ('425', 'thunders_edge'),
#  ('426', 'battle_bulge'),
#  ('427', 'grass'),
#  ('428', 'galopp_royal'),
#  ('429', 'magalon'),
#  ('430', 'asterix_das_kartenspiel'),
#  ('431', 'alhambra_card_game'),
#  ('432', '6_nimmt'),
#  ('433', 'shark'),
#  ('434', 'yucata'),
#  ('436', 'canyon'),
#  ('437', 'master_labyrinth'),
#  ('438', 'scotland_yard'),
#  ('440', 'zoff_buffalo'),
#  ('441', 'filthy_rich'),
#  ('442', 'um_reifenbreite'),
#  ('443', 'code_777'),
#  ('444', 'escape_hidden_castle'),
#  ('445', 'die_osterinsel'),
#  ('446', 'avalanche'),
#  ('449', 'great_balloon_race'),
#  ('450', 'octi'),
#  ('451', 'beutelschneider'),
#  ('452', 'mummy_rummy'),
#  ('453', 'bohnanza_la_isla_bohnita'),
#  ('454', 'tante_tarantel'),
#  ('455', 'am_fuss_des_kilimandscharo'),
#  ('457', 'jumbo_grand_prix'),
#  ('458', 'sherlock_holmes_card_game'),
#  ('459', 'ausgebremst'),
#  ('460', 'railway_rivals'),
#  ('461', 'freibeuter'),
#  ('462', 'esels_rennen'),
#  ('463', 'magic_gathering'),
#  ('464', 'billabong'),
#  ('465', 'zankapfel'),
#  ('466', 'inkognito'),
#  ('467', 'bohnanza_erweiterungs_set'),
#  ('468', 'dump'),
#  ('469', 'teufels_kuche'),
#  ('470', 'road_white_house'),
#  ('471', 'totem'),
#  ('472', 'dungeonquest'),
#  ('473', 'ole'),
#  ('474', 'cold_war'),
#  ('475', 'taj_mahal'),
#  ('476', 'mr_president'),
#  ('477', 'broadway_game'),
#  ('478', 'citadels'),
#  ('479', 'bambuti'),
#  ('480', 'age_arguments'),
#  ('481', 'carolus_magnus'),
#  ('482', 'sky_runner'),
#  ('483', 'diplomacy'),
#  ('484', 'stratego_legends'),
#  ('485', 'galloping_pigs'),
#  ('486', 'barnyard_buddies'),
#  ('487', 'power'),
#  ('488', 'stake_your_claim'),
#  ('489', 'pacal'),
#  ('490', 'warangel'),
#  ('491', 'web_power'),
#  ('492', 'aladdins_dragons'),
#  ('494', 'ave_caesar'),
#  ('495', 'time_pirates'),
#  ('496', 'dilemma'),
#  ('497', 'vampire'),
#  ('498', 'sufferin_spirits'),
#  ('499', 'arbos'),
#  ('500', 'mark'),
#  ('501', 'dschungelrennen'),
#  ('502', 'bretonenboule'),
#  ('503', 'through_desert'),
#  ('504', 'die_verbotene_stadt'),
#  ('505', 'goldener_drache'),
#  ('506', 'big_cheese'),
#  ('507', 'cartel'),
#  ('508', 'blue_max'),
#  ('509', 'reef'),
#  ('510', 'eschnapur'),
#  ('511', 'silverton'),
#  ('512', 'holiday'),
#  ('513', 'warchest'),
#  ('514', 'true_colors'),
#  ('515', '6_tage_rennen'),
#  ('517', 'shark_bait'),
#  ('518', 'cat_vs_mouse'),
#  ('519', 'mush'),
#  ('520', 'axis_allies_europe'),
#  ('521', 'crokinole'),
#  ('524', 'desperados'),
#  ('525', 'pisa'),
#  ('526', 'abalone'),
#  ('527', 'gipf'),
#  ('528', 'zertz'),
#  ('529', 'charlemagne'),
#  ('530', 'entenrallye'),
#  ('531', 'merchants_amsterdam'),
#  ('533', 'labyrinth_card_game'),
#  ('534', 'ny_chase'),
#  ('535', 'power_barons'),
#  ('536', 'visionary'),
#  ('537', 'ice_blocks'),
#  ('538', 'manager'),
#  ('539', 'dampfross'),
#  ('540', 'sisimizi'),
#  ('541', 'das_motorsportspiel'),
#  ('542', 'animocrazy'),
#  ('545', 'kaleidos'),
#  ('547', 'flohzirkus'),
#  ('548', 'buck_rogers_battle_25th_century_game'),
#  ('549', 'aerodrome'),
#  ('550', 'barbarossa'),
#  ('551', 'battle_cry'),
#  ('552', 'bus'),
#  ('553', 'chez_geek'),
#  ('554', 'la_citta'),
#  ('555', 'princes_florence'),
#  ('556', '7_safari'),
#  ('557', 'laguna'),
#  ('558', 'der_weisse_lotus'),
#  ('559', 'metro'),
#  ('561', 'flusspiraten'),
#  ('562', 'silberzwerg'),
#  ('563', 'doolittle_waite'),
#  ('564', 'die_seidenstrasse'),
#  ('565', 'port_royal'),
#  ('566', 'wongar'),
#  ('567', 'quartier_latin'),
#  ('568', 'rage'),
#  ('569', 'maestro'),
#  ('570', 'terrain_game'),
#  ('571', 'papua'),
#  ('572', 'battle_cattle'),
#  ('573', 'grand_prix'),
#  ('574', 'devil_take_hindmost'),
#  ('575', 'das_kollier'),
#  ('576', 'illuminati_y2k'),
#  ('577', 'parts_unknown'),
#  ('578', 'protzen'),
#  ('579', 'field_fire'),
#  ('581', 'tile_chess'),
#  ('582', 'kampf_um_rom'),
#  ('583', 'el_grande_expansions'),
#  ('585', 'kardinal'),
#  ('586', 'front'),
#  ('587', 'sumera'),
#  ('589', 'wiz_war'),
#  ('590', 'mille_bornes'),
#  ('592', 'spades'),
#  ('593', 'favoriten'),
#  ('594', 'sleuth'),
#  ('595', 'escape_elba'),
#  ('596', 'trolley_car'),
#  ('597', 'el_grande_grandissimo'),
#  ('599', 'stack_21'),
#  ('600', 'die_weinhandler'),
#  ('601', 'take_two'),
#  ('602', 'animal_poker'),
#  ('603', 'putsch'),
#  ('604', 'verrat'),
#  ('605', 'banana_republic'),
#  ('606', 'pico_2'),
#  ('607', 'honor_samurai'),
#  ('608', 'siesta'),
#  ('609', 'ferkelei'),
#  ('610', 'knights_rainbow'),
#  ('611', 'ironman_football'),
#  ('612', 'kippit'),
#  ('613', 'overboard'),
#  ('614', 'rubiks_race'),
#  ('615', 'cube_fusion'),
#  ('616', 'whats_my_head'),
#  ('617', 'alles_futsch'),
#  ('618', 'mlb_showdown'),
#  ('619', 'bottle_imp'),
#  ('620', 'we_people'),
#  ('621', '25_words_or_less'),
#  ('622', 'change'),
#  ('623', 'swashbuckler_game_swordplay_and_derring_do'),
#  ('624', 'quoridor'),
#  ('625', 'business'),
#  ('626', 'war_and_peace'),
#  ('627', 'royal_tank_corps'),
#  ('629', 'q_turn'),
#  ('630', 'double_quick'),
#  ('631', 'daytona_500'),
#  ('632', 'cloud_9'),
#  ('633', 'elixir'),
#  ('634', 'river_dragons'),
#  ('635', 'formula_motor_racing'),
#  ('636', 'blindside'),
#  ('637', 'stock_car_championship_racing_card_game'),
#  ('638', 'hera_and_zeus'),
#  ('639', 'american_megafauna'),
#  ('642', 'oodles'),
#  ('643', 'deadlands_doomtown_range_wars'),
#  ('644', 'shipwrecked'),
#  ('645', 'bosworth'),
#  ('646', 'pirates_plunder'),
#  ('647', 'mystick_domination'),
#  ('648', 'vox_populi'),
#  ('649', 'thieves_bagdad'),
#  ('650', 'fairy_meat'),
#  ('651', 'zero_down'),
#  ('652', 'x_net'),
#  ('653', 'shit'),
#  ('655', 'castle'),
#  ('657', 'munchhausen'),
#  ('660', 'riffifi'),
#  ('661', 'wheres_bobs_hat'),
#  ('663', 'siege'),
#  ('664', 'shift'),
#  ('665', 'quackshot'),
#  ('666', 'stump'),
#  ('667', 'refugium'),
#  ('668', 'sternenhimmel'),
#  ('669', 'plague_pestilence'),
#  ('670', 'starship_troopers'),
#  ('671', 'bull_run_first_major_battle_american_civil_war'),
#  ('673', 'star_traders'),
#  ('674', 'jump_unknown'),
#  ('675', '4th_dimension'),
#  ('676', 'ninja_wars'),
#  ('677', 'would_you_rather'),
#  ('678', 'x_it'),
#  ('679', 'minion_hunter'),
#  ('680', 'dune'),
#  ('681', 'quarto'),
#  ('683', 'timeline'),
#  ('684', 'monopoly_card_game'),
#  ('685', 'marrakesh'),
#  ('686', 'dr_jekyll_mr_hyde'),
#  ('687', 'cabale'),
#  ('688', 'manchu_taiping_rebellion_1852_1868'),
#  ('689', 'dubble_kross'),
#  ('690', 'singapore'),
#  ('691', 'timbuktu'),
#  ('692', 'wizard_kings'),
#  ('695', 'fibonacci'),
#  ('696', 'big_idea'),
#  ('697', 'conspiracy'),
#  ('698', 'gother_thou'),
#  ('699', 'heroquest'),
#  ('700', 'battle_masters'),
#  ('701', 'house_divided_war_between_states_1861_65'),
#  ('702', 'wabbit_wampage'),
#  ('703', 'roman_civil_war'),
#  ('704', 'montgolfiere'),
#  ('705', 'caesar_gallia_conquest_ancient_frontier'),
#  ('706', 'frederick_great_campaigns_soldier_king_1756_1759'),
#  ('707', 'when_tigers_fight'),
#  ('708', 'holy_war_afghanistan'),
#  ('709', 'dragons_glory'),
#  ('710', 'snits_revenge'),
#  ('711', 'elfenroads'),
#  ('712', 'blood_bowl_third_edition'),
#  ('713', 'nuclear_war'),
#  ('714', 'talisman'),
#  ('715', 'escape_colditz'),
#  ('716', 'pizza_party'),
#  ('718', 'galaxy_dark_ages'),
#  ('719', 'tyranno_ex'),
#  ('720', 'fast_food_franchise'),
#  ('721', 'oregon_trail'),
#  ('722', 'over_edge'),
#  ('723', 'uncanny_x_men_alert_adventure_game'),
#  ('724', 'chill_black_morn_manor'),
#  ('725', 'triple_threat_baseball'),
#  ('727', 'chinese_civil_war'),
#  ('728', 'sun_never_sets_three_campaigns_british_empire'),
#  ('730', 'breakout_normandy'),
#  ('731', 'escape_new_york'),
#  ('732', 'dont_make_me_laugh'),
#  ('733', 'dont_make_me_laugh_jr'),
#  ('734', 'strange_true'),
#  ('735', 'hollywoods_reel_schpeel'),
#  ('736', 'san_francisco'),
#  ('738', 'matheeno'),
#  ('739', 'ultimate_soccer_america'),
#  ('740', 'rio_grande_battle_valverde'),
#  ('741', 'trajan'),
#  ('742', 'germania'),
#  ('744', 'wicked_words'),
#  ('745', 'war_resistance'),
#  ('746', 'game_france_1940_german_blitzkrieg_west'),
#  ('747', 'bitter_woods_battle_bulge'),
#  ('748', 'trax'),
#  ('749', 'dutch_mountains'),
#  ('750', 'shocks_scares'),
#  ('751', 'minos'),
#  ('752', 'maul_america'),
#  ('753', 'panzerkrieg_von_manstein_heeresgruppe_sud'),
#  ('754', 'domain'),
#  ('755', 'thunder_cassino'),
#  ('756', 'black_vienna'),
#  ('757', 'lunatix_loop'),
#  ('758', 'balmy_balloonists'),
#  ('759', 'turning_point_stalingrad'),
#  ('760', 'battle_line'),
#  ('761', 'great_brain_robbery'),
#  ('762', 'formula_c_minus'),
#  ('764', 'mad_gab'),
#  ('765', 'space_walk'),
#  ('766', 'regatta'),
#  ('767', 'keywood'),
#  ('768', 'keytown'),
#  ('769', 'star_trek_red_alert'),
#  ('770', 'loot'),
#  ('771', 'kings_and_castles'),
#  ('772', 'ausbrecher_ag'),
#  ('773', 'beim_zeus'),
#  ('774', 'buddel_bande'),
#  ('775', 'die_tafelrunde'),
#  ('776', 'remmi_demmi'),
#  ('778', 'auction_america_trivia_game_any_collector'),
#  ('780', 'big_battle'),
#  ('781', 'tabloid_teasers'),
#  ('782', 'win_place_show'),
#  ('783', 'letter_head'),
#  ('784', 'discretion'),
#  ('785', 'dog_eat_dog'),
#  ('786', 'maxi_boure'),
#  ('787', 'palermo'),
#  ('788', 'tales_arabian_nights'),
#  ('789', 'focus'),
#  ('790', 'terra_turrium'),
#  ('791', 'lowendynastie'),
#  ('792', 'megiddo'),
#  ('793', 'yahtzee_deluxe_poker'),
#  ('794', 'foil'),
#  ('795', 'dragonlance'),
#  ('796', 'shanghai_trader'),
#  ('797', 'flucht_aus_mangrovia'),
#  ('798', 'ace_aces_handy_rotary_series'),
#  ('799', 'hills_rise_wild'),
#  ('800', 'camlyns_destiny'),
#  ('801', 'crimean_war_battles'),
#  ('802', 'taipei_china_invades'),
#  ('803', 'dragonhunt'),
#  ('804', 'thunder_road'),
#  ('805', 'buffy_vampire_slayer_game'),
#  ('806', 'west_riding'),
#  ('808', 'pipeline_oil_game'),
#  ('810', 'amoeba'),
#  ('811', 'rummikub'),
#  ('813', 'goosebumps_terror_graveyard_game'),
#  ('814', 'aquarius'),
#  ('815', 'chrononauts'),
#  ('816', '2038_tycoons_asteroid_belt'),
#  ('819', 'quacksalbe'),
#  ('820', 'axiom'),
#  ('821', 'la_trel'),
#  ('822', 'carcassonne'),
#  ('823', 'lord_rings'),
#  ('824', 'hijara'),
#  ('825', 'screaming_eagles'),
#  ('826', 'cartagena'),
#  ('827', 'attila'),
#  ('828', 'wizards'),
#  ('829', 'battle_bands'),
#  ('830', 'fib_or_not'),
#  ('831', 'schrille_stille'),
#  ('833', 'people'),
#  ('834', 'chronology'),
#  ('835', 'election'),
#  ('836', 'new_england_railways'),
#  ('840', 'corsairs'),
#  ('841', 'razzia'),
#  ('843', 'circus_minimus'),
#  ('844', 'mausoleum'),
#  ('847', 'feudal'),
#  ('848', 'tip_tap'),
#  ('849', 'golf_masters'),
#  ('852', 'pop_belly'),
#  ('853', 'und_tschuss'),
#  ('854', 'doge'),
#  ('855', 'java'),
#  ('856', 'new_york_new_york'),
#  ('857', 'titanic_der_mythos'),
#  ('858', 'blindes_huhn'),
#  ('859', 'illuminati'),
#  ('860', 'scotland_brave'),
#  ('861', 'weapons_warriors_castle_combat_set'),
#  ('864', 'mage_knight'),
#  ('865', 'landslide'),
#  ('866', 'lie_cheat_steal'),
#  ('867', 'morisi'),
#  ('868', 'atlantis'),
#  ('869', 'bongo'),
#  ('870', 'empires_ancient_world'),
#  ('871', 'fire'),
#  ('872', 'm'),
#  ('873', 'offline'),
#  ('874', 'pythago'),
#  ('875', 'roads_boats'),
#  ('876', 'tennis_masters'),
#  ('877', 'troia'),
#  ('878', 'wyatt_earp'),
#  ('879', 'tacara'),
#  ('882', 'derby'),
#  ('883', 'ivanhoe'),
#  ('884', 'way_out_west'),
#  ('886', 'der_garten_des_sonnenkonigs'),
#  ('890', 'real_action_stockcar_championship'),
#  ('891', 'cranium'),
#  ('892', 'ad_mania'),
#  ('893', 'smuggle'),
#  ('894', 'lifelinks'),
#  ('895', 'apba_pro_baseball'),
#  ('896', 'stir_crazy'),
#  ('897', 'dear_abby'),
#  ('898', 'initial_reaction'),
#  ('899', 'movie_mania'),
#  ('900', 'city'),
#  ('902', 'meuterer'),
#  ('903', 'hamsterrolle'),
#  ('904', 'nightmare_productions'),
#  ('905', 'vagabondo'),
#  ('906', 'abilene'),
#  ('907', 'beheaded'),
#  ('908', 'tally_ho'),
#  ('909', 'saturn'),
#  ('910', 'kunst_stucke'),
#  ('911', 'empires_middle_ages'),
#  ('912', 'pacific_victory_war_pacific_1941_45'),
#  ('913', 'high_bohn'),
#  ('914', 'battle_platform_antilles'),
#  ('915', 'mystery_abbey'),
#  ('916', 'pete_pirate'),
#  ('917', 'rack_o'),
#  ('920', 'ultimate_outburst'),
#  ('923', 'breakaway_rider'),
#  ('925', 'werewolf'),
#  ('926', 'catan_cities_knights'),
#  ('927', 'lift'),
#  ('928', 'geruchtekuche'),
#  ('929', 'great_dalmuti'),
#  ('930', 'bose_buben'),
#  ('931', 'corner'),
#  ('932', 'top_race'),
#  ('933', 'new_orleans_big_band'),
#  ('934', 'die_kette_von_saba'),
#  ('935', 'australian_rails'),
#  ('936', 'fury_dracula'),
#  ('937', '1825_unit_1'),
#  ('938', 'enchanted_forest'),
#  ('939', 'star_wars_queens_gambit'),
#  ('940', 'karawane'),
#  ('941', 'turbo_taxi'),
#  ('942', 'snails_pace'),
#  ('943', 'ligretto'),
#  ('944', 'magblast'),
#  ('945', 'nametrain'),
#  ('946', 'rolazone'),
#  ('947', 'trivia_dummies'),
#  ('948', 'dao'),
#  ('949', 'twixt'),
#  ('950', 'four_dragons'),
#  ('951', 'football_strategy'),
#  ('954', 'pony_express'),
#  ('955', 'super_giant_monster_showdown'),
#  ('956', 'azteca'),
#  ('957', 'panzerzug'),
#  ('958', 'orcz'),
#  ('959', 'luftschiff'),
#  ('960', 'grapple'),
#  ('961', 'zoki'),
#  ('962', 'contango'),
#  ('963', 'gardens_alhambra'),
#  ('964', 'kapitan_wackelpudding'),
#  ('965', 'ben_hurt'),
#  ('967', 'kommissar_x'),
#  ('972', 'seven_deadly_sins'),
#  ('975', 'keep'),
#  ('979', 'powerpuff_girls_saving_world_bedtime'),
#  ('980', 'al_cabohne'),
#  ('982', 'amoeba_wars'),
#  ('983', 'tangoes'),
#  ('984', 'name_burst'),
#  ('985', 'corner_market'),
#  ('986', 'babel'),
#  ('987', 'kingmaker'),
#  ('988', 'zapp_zerapp'),
#  ('989', '1848'),
#  ('990', '90_grad'),
#  ('992', 'alcazar'),
#  ('993', 'den_ufern_des_nils'),
#  ('994', 'auf_trab_im_sulkydrom'),
#  ('995', 'svea_rike_batalj'),
#  ('997', 'canaletto'),
#  ('999', 'panda_monium'),
#  ('1000', 'corona'),
#  ('1001', 'vendetta'),
#  ('1002', 'cosmic_eidex'),
#  ('1003', 'das_regeln_wir_schon'),
#  ('1004', 'der_feuersalamander'),
#  ('1005', 'der_tiger_ist_los'),
#  ('1006', 'die_erbraffer'),
#  ('1007', 'die_hanse'),
#  ('1008', 'die_schlangen_von_delhi'),
#  ('1010', 'diver'),
#  ('1011', 'dream_team'),
#  ('1012', 'die_magier'),
#  ('1013', 'energie_poker'),
#  ('1014', 'fief_2'),
#  ('1015', 'finger_weg_von_mona_lisa'),
#  ('1016', 'finito'),
#  ('1017', 'fresh_fish'),
#  ('1018', 'galaxis'),
#  ('1019', 'le_gang_des_traction_avant'),
#  ('1020', 'canyon_grand_canyon'),
#  ('1021', 'harun'),
#  ('1023', 'himalaya'),
#  ('1027', 'konzern'),
#  ('1028', 'kraut_ruben'),
#  ('1029', 'lieber_bairisch_sterben'),
#  ('1031', 'tv_wars'),
#  ('1032', 'b_17_queen_skies'),
#  ('1033', 'xenophon_10000_against_persia'),
#  ('1035', 'squad_leader'),
#  ('1036', 'speculation'),
#  ('1037', 'deadlands_doomtown'),
#  ('1038', 'tantrix'),
#  ('1041', 'san_marco'),
#  ('1042', 'dragons_gold'),
#  ('1043', 'pitstop'),
#  ('1044', 'gunslinger'),
#  ('1045', 'malawi'),
#  ('1046', 'maxx'),
#  ('1047', 'mem'),
#  ('1050', 'momo'),
#  ('1051', 'mutternland'),
#  ('1053', 'orbit'),
#  ('1054', 'pacific_northwest_rails'),
#  ('1055', 'paule_panik'),
#  ('1056', 'piratenpoker'),
#  ('1057', 'pow_wow'),
#  ('1058', 'rockets'),
#  ('1061', 'sansibar'),
#  ('1063', 'schraumen'),
#  ('1065', 'vigo'),
#  ('1066', 'zargos'),
#  ('1068', 'ordino'),
#  ('1069', 'head_quarter'),
#  ('1070', 'shadows_forest'),
#  ('1071', 'aztec'),
#  ('1072', 'watn_dat'),
#  ('1073', 'der_schatz_der_inka'),
#  ('1075', 'big_bang'),
#  ('1076', 'captain_future'),
#  ('1077', 'baubylon'),
#  ('1079', 'tokami'),
#  ('1080', 'evolution'),
#  ('1081', 'die_schlacht_der_dinosaurier'),
#  ('1082', 'invers'),
#  ('1083', 'hexenjagd'),
#  ('1084', 'das_gold_der_maya'),
#  ('1085', 'kaminett'),
#  ('1086', 'der_schatz_der_erdgeister'),
#  ('1087', 'matschig'),
#  ('1088', 'luftschlosser'),
#  ('1089', 'feuer_und_wasser'),
#  ('1090', 'yoyo'),
#  ('1091', 'explosiv'),
#  ('1092', 'die_goldene_eins'),
#  ('1093', 'jolly_roger'),
#  ('1094', 'assassin'),
#  ('1095', 'mystery_nile'),
#  ('1096', 'four_real'),
#  ('1097', 'dont_give_your_day_job'),
#  ('1098', 'judge_dredd'),
#  ('1099', 'downspin'),
#  ('1100', 'check_ripper'),
#  ('1101', 'flying_carpet'),
#  ('1104', 'kiezkonig'),
#  ('1105', 'titus'),
#  ('1107', 'nyet'),
#  ('1109', 'last_minute'),
#  ('1110', 'kathai'),
#  ('1111', 'taboo'),
#  ('1114', 'botany_bay'),
#  ('1115', 'poker'),
#  ('1116', 'oh_hell'),
#  ('1117', 'youre_bluffing'),
#  ('1120', 'silver_mine'),
#  ('1122', 'dry_gulch'),
#  ('1125', 'big_shot'),
#  ('1126', 'car_wars_card_game'),
#  ('1127', 'encounters'),
#  ('1129', 'archimedes'),
#  ('1130', 'halali'),
#  ('1132', 'top_secret'),
#  ('1133', 'organized_crime'),
#  ('1134', 'road_warrior'),
#  ('1135', 'quest_power'),
#  ('1136', 'domain_warlocks_challenge'),
#  ('1137', 'die_siedler_von_catan_das_buch_zum_spielen'),
#  ('1138', 'army_darkness'),
#  ('1139', 'fantastische_ballonreise'),
#  ('1140', 'ballonrennen'),
#  ('1141', 'pass_gas'),
#  ('1142', 'sabotage'),
#  ('1143', 'warrior_knights'),
#  ('1144', 'warlock_firetop_mountain'),
#  ('1145', 'city_chaos'),
#  ('1146', 'shadowlord'),
#  ('1147', 'outrage_steal_crown_jewels'),
#  ('1148', 'eagle_kingdoms'),
#  ('1149', 'dragon_strike'),
#  ('1150', 'lionheart'),
#  ('1151', 'money_power_respect'),
#  ('1152', 'mystic_wood'),
#  ('1154', 'nuts_you'),
#  ('1155', 'capitol'),
#  ('1156', 'bram_stokers_dracula_board_game'),
#  ('1157', 'save_doctor_lucky'),
#  ('1158', 'rus_rise_russia_20_bc_ad1584'),
#  ('1159', 'evo'),
#  ('1160', 'boom_town'),
#  ...]

# %%
df = pd.DataFrame(id_list,columns=['game_id',
                                  'game_name'])

df['game_id'] = df['game_id'].astype(int)

# %%
df
# Out:
#         game_id                                          game_name
# 0             1                                         die_macher
# 1             2                                       dragonmaster
# 2             3                                            samurai
# 3             4                                     tal_der_konige
# 4             5                                            acquire
# ...         ...                                                ...
# 145503   392703                                          alpenglow
# 145504   392704            os_desejos_do_sultao_expansao_viajantes
# 145505   392705  atlantis_rising_monstrosities_here_there_be_mo...
# 145506   392707             dawn_heroes_annas_roundtable_expansion
# 145507   392712                                geheime_botschaften
#
# [145508 rows x 2 columns]

# %%
df.to_csv('all_game_ids.csv')

# %%
# Check for duplicates
duplicates = df[df.duplicated('game_id',keep=False)]

# %%
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [game_id, game_name]
# Index: []
