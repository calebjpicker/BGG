# %%
import os
import sqlite3
from bs4 import BeautifulSoup
import pandas as pd
import xml.etree.ElementTree as ET

# %%
# Open SQL connected to bgg_.db
file_path = '../Board Game Geek/bgg_.db'
con = sqlite3.connect(file_path)
cur = con.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7944\4272008160.py in <module>
#       1 # Open SQL connected to bgg_.db
#       2 file_path = '../Board Game Geek/bgg_.db'
# ----> 3 con = sqlite3.connect(file_path)
#       4 cur = con.cursor()
#
# OperationalError: unable to open database file

# %%
# Query bgg_.db to get list of game_ids
# Select list of game_ids from table
# This game_id_list is list of all game_ids generated from BGG website
game_id_list = []

results = cur.execute("SELECT id as id_ FROM games")
results = results.fetchall()

for num in results:
    game_id_list.append(num[0])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7944\1510596298.py in <module>
#       4 game_id_list = []
#       5
# ----> 6 results = cur.execute("SELECT id as id_ FROM games")
#       7 results = results.fetchall()
#       8
#
# OperationalError: no such table: games

# %%
# Load one xml file and view its contents
game_id_list = []
game_id_list.append(1)

# Specify relative file path
cache_folder = '../cache/'

# Specify XML filename
game_id = game_id_list[0]
xml_file_name = f"{game_id}.xml"

# Get current directory to combine with relative path
current_directory = os.getcwd()

# XML file path
xml_file_path = os.path.abspath(os.path.join(current_directory,cache_folder,xml_file_name))

# Load the XML file
with open(xml_file_path, 'r', encoding='utf-8') as file:
    xml_contents = file.read()

# Create beautiful soup object
soup = BeautifulSoup(xml_contents,'xml')



# print(results_tags)

# Print the xml content
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <items termsofuse="https://boardgamegeek.com/xmlapi/termsofuse">
#  <item id="1" type="boardgame">
#   <thumbnail>
#    https://cf.geekdo-images.com/rpwCZAjYLD940NWwP3SRoA__thumb/img/YT6svCVsWqLrDitcMEtyazVktbQ=/fit-in/200x150/filters:strip_icc()/pic4718279.jpg
#   </thumbnail>
#
#    https://cf.geekdo-images.com/rpwCZAjYLD940NWwP3SRoA__original/img/yR0aoBVKNrAmmCuBeSzQnMflLYg=/0x0/filters:format(jpeg)/pic4718279.jpg
#
#   <name sortindex="5" type="primary" value="Die Macher"/>
#   <name sortindex="1" type="alternate" value="德国大选"/>
#   <name sortindex="1" type="alternate" value="디 마허"/>
#   <description>
#    Die Macher is a game about seven sequential political races in different regions of Germany. Players are in charge of national political parties, and must manage limited resources to help their party to victory. The winning party will have the most victory points after all the regional elections. There are four different ways of scoring victory points. First, each regional election can supply one to eighty victory points, depending on the size of the region and how well your party does in it. Second, if a party wins a regional election and has some media influence in the region, then the party will receive some media-control victory points. Third, each party has a national party membership which will grow as the game progresses and this will supply a fair number of victory points. Lastly, parties score some victory points if their party platform matches the national opinions at the end of the game.&amp;#10;&amp;#10;The 1986 edition featured four parties from the old West Germany and supported 3-4 players. The 1997 edition supports up to five players in the re-united Germany and updated several features of the rules as well.  The 2006 edition also supports up to five players and adds a shorter five-round variant and additional rules updates by the original designer.&amp;#10;&amp;#10;
#   </description>
#   <yearpublished value="1986"/>
#   <minplayers value="3"/>
#   <maxplayers value="5"/>
#   <poll name="suggested_numplayers" title="User Suggested Number of Players" totalvotes="135">
#    <results numplayers="1">
#     <result numvotes="0" value="Best"/>
#     <result numvotes="1" value="Recommended"/>
#     <result numvotes="85" value="Not Recommended"/>
#    </results>
#    <results numplayers="2">
#     <result numvotes="0" value="Best"/>
#     <result numvotes="1" value="Recommended"/>
#     <result numvotes="87" value="Not Recommended"/>
#    </results>
#    <results numplayers="3">
#     <result numvotes="2" value="Best"/>
#     <result numvotes="26" value="Recommended"/>
#     <result numvotes="75" value="Not Recommended"/>
#    </results>
#    <results numplayers="4">
#     <result numvotes="25" value="Best"/>
#     <result numvotes="86" value="Recommended"/>
#     <result numvotes="9" value="Not Recommended"/>
#    </results>
#    <results numplayers="5">
#     <result numvotes="116" value="Best"/>
#     <result numvotes="11" value="Recommended"/>
#     <result numvotes="2" value="Not Recommended"/>
#    </results>
#    <results numplayers="5+">
#     <result numvotes="1" value="Best"/>
#     <result numvotes="0" value="Recommended"/>
#     <result numvotes="62" value="Not Recommended"/>
#    </results>
#   </poll>
#   <playingtime value="240"/>
#   <minplaytime value="240"/>
#   <maxplaytime value="240"/>
#   <minage value="14"/>
#   <poll name="suggested_playerage" title="User Suggested Player Age" totalvotes="31">
#    <results>
#     <result numvotes="0" value="2"/>
#     <result numvotes="0" value="3"/>
#     <result numvotes="0" value="4"/>
#     <result numvotes="0" value="5"/>
#     <result numvotes="0" value="6"/>
#     <result numvotes="0" value="8"/>
#     <result numvotes="0" value="10"/>
#     <result numvotes="6" value="12"/>
#     <result numvotes="18" value="14"/>
#     <result numvotes="4" value="16"/>
#     <result numvotes="2" value="18"/>
#     <result numvotes="1" value="21 and up"/>
#    </results>
#   </poll>
#   <poll name="language_dependence" title="Language Dependence" totalvotes="48">
#    <results>
#     <result level="1" numvotes="36" value="No necessary in-game text"/>
#     <result level="2" numvotes="5" value="Some necessary text - easily memorized or small crib sheet"/>
#     <result level="3" numvotes="7" value="Moderate in-game text - needs crib sheet or paste ups"/>
#     <result level="4" numvotes="0" value="Extensive use of text - massive conversion needed to be playable"/>
#     <result level="5" numvotes="0" value="Unplayable in another language"/>
#    </results>
#   </poll>
#   <link id="1021" type="boardgamecategory" value="Economic"/>
#   <link id="1026" type="boardgamecategory" value="Negotiation"/>
#   <link id="1001" type="boardgamecategory" value="Political"/>
#   <link id="2916" type="boardgamemechanic" value="Alliances"/>
#   <link id="2080" type="boardgamemechanic" value="Area Majority / Influence"/>
#   <link id="2012" type="boardgamemechanic" value="Auction/Bidding"/>
#   <link id="2072" type="boardgamemechanic" value="Dice Rolling"/>
#   <link id="2040" type="boardgamemechanic" value="Hand Management"/>
#   <link id="2020" type="boardgamemechanic" value="Simultaneous Action Selection"/>
#   <link id="10643" type="boardgamefamily" value="Country: Germany"/>
#   <link id="34116" type="boardgamefamily" value="Political: Elections"/>
#   <link id="91" type="boardgamefamily" value="Series: Classic Line (Valley Games)"/>
#   <link id="1" type="boardgamedesigner" value="Karl-Heinz Schmiel"/>
#   <link id="12517" type="boardgameartist" value="Marcus Gschwendtner"/>
#   <link id="4959" type="boardgameartist" value="Harald Lieske"/>
#   <link id="133" type="boardgamepublisher" value="Hans im Glück"/>
#   <link id="2" type="boardgamepublisher" value="Moskito Spiele"/>
#   <link id="24883" type="boardgamepublisher" value="Ediciones MasQueOca"/>
#   <link id="2726" type="boardgamepublisher" value="Portal Games"/>
#   <link id="15108" type="boardgamepublisher" value="Spielworxx"/>
#   <link id="39249" type="boardgamepublisher" value="sternenschimmermeer"/>
#   <link id="11652" type="boardgamepublisher" value="Stronghold Games"/>
#   <link id="5382" type="boardgamepublisher" value="Valley Games, Inc."/>
#   <link id="8147" type="boardgamepublisher" value="YOKA Games"/>
#   <statistics page="1">
#    <ratings>
#     <usersrated value="5661"/>
#     <average value="7.59864"/>
#     <bayesaverage value="7.0577"/>
#     <ranks>
#      <rank bayesaverage="7.0577" friendlyname="Board Game Rank" id="1" name="boardgame" type="subtype" value="384"/>
#      <rank bayesaverage="7.19178" friendlyname="Strategy Game Rank" id="5497" name="strategygames" type="family" value="221"/>
#     </ranks>
#     <stddev value="1.57457"/>
#     <median value="0"/>
#     <owned value="7973"/>
#     <trading value="258"/>
#     <wanting value="507"/>
#     <wishing value="2119"/>
#     <numcomments value="2065"/>
#     <numweights value="777"/>
#     <averageweight value="4.3153"/>
#    </ratings>
#   </statistics>
#  </item>
# </items>

# %%
# Scrape game details from cache folder

cached_folder = '..\cache' # Cached folder name
basic_game_info_list = []
test_cache_xml = [1]
print(basic_game_info_list)
print(test_cache_xml)

for game_id in test_cache_xml:
    print(f"Processing game id: {game_id}") # Debug print the game_id currently being processed
    xml_file_path = os.path.join(cached_folder,f"{game_id}.xml") # creates full folder path and file name for a game id
    print(f"The file path is: {xml_file_path}")
    # Parse the XML data by reading xml file contents
    try:
        with open(xml_file_path, 'r', encoding='utf-8') as file:
            content = file.read()
        soup = BeautifulSoup(content,"lxml")
        print("Parsed XML data.")  # Debug print
    except FileNotFoundError:
        print(f"XML file not found for game id: {game_id}")
        continue
    
    try:
        # Get the main info on a game from search_url
        release_year_info = soup.find("yearpublished")
        min_players_info = soup.find("minplayers")
        max_players_info = soup.find("maxplayers")
        game_desc_info = soup.find("description")
        min_age_info = soup.find("minage")
        playtime_info = soup.find("playingtime")
        min_playtime_info = soup.find("minplaytime")
        max_playtime_info = soup.find("maxplaytime")
    except AttributeError:
        print(f"There was an AttributeError: {AttributeError}")
        continue # Skip to next iteration
    
    # Extract single values for a given game id
    try:
        release_year = release_year_info.get('value') if release_year_info else 'N/A'
        game_desc = game_desc_info.text.strip() if game_desc_info else 'N/A'
        min_players = min_players_info.get('value') if min_players_info else 'N/A'
        max_players = max_players_info.get('value') if max_players_info else 'N/A'
        min_age = min_age_info.get('value') if min_age_info else 'N/A'
        playtime = playtime_info.get('value') if playtime_info else 'N/A'
        min_playtime = min_playtime_info.get('value') if min_playtime_info else 'N/A'
        max_playtime = max_playtime_info.get('value') if max_playtime_info else 'N/A'
    except ValueError as e:
        print(f"ValueError for game id: {game_id}")
        continue # Skip to next iteration
    
    
    basic_game_info_list.append([game_id,release_year,game_desc,min_players,max_players,
                                 min_age,playtime,min_playtime,max_playtime])
    print(f"Appended data for game id: {game_id}")  # Debug print

print("Completed loop.")  # Debug print
# Out:
# []
# [1]
# Processing game id: 1
# The file path is: ..\cache\1.xml
# Parsed XML data.
# Appended data for game id: 1
# Completed loop.

# %%
basic_game_info_list
# Out:
# [[1,
#   '1986',
#   'Die Macher is a game about seven sequential political races in different regions of Germany. Players are in charge of national political parties, and must manage limited resources to help their party to victory. The winning party will have the most victory points after all the regional elections. There are four different ways of scoring victory points. First, each regional election can supply one to eighty victory points, depending on the size of the region and how well your party does in it. Second, if a party wins a regional election and has some media influence in the region, then the party will receive some media-control victory points. Third, each party has a national party membership which will grow as the game progresses and this will supply a fair number of victory points. Lastly, parties score some victory points if their party platform matches the national opinions at the end of the game.&#10;&#10;The 1986 edition featured four parties from the old West Germany and supported 3-4 players. The 1997 edition supports up to five players in the re-united Germany and updated several features of the rules as well.  The 2006 edition also supports up to five players and adds a shorter five-round variant and additional rules updates by the original designer.&#10;&#10;',
#   '3',
#   '5',
#   '14',
#   '240',
#   '240',
#   '240']]

# %%
df = pd.DataFrame(basic_game_info_list,columns=['game_id','release_year','game_desc','min_players','max_players',
                                 'min_age','playtime','min_playtime','max_playtime'])

df['game_id'] = df['game_id'].astype(int)
df['release_year'] = df['release_year'].astype(int)
df['min_players'] = df['min_players'].astype(int)
df['max_players'] = df['max_players'].astype(int)
df['min_age'] = df['min_age'].astype(int)
df['playtime'] = df['playtime'].astype(int)
df['min_playtime'] = df['min_playtime'].astype(int)
df['max_playtime'] = df['max_playtime'].astype(int)

# %%
#### THIS WORKS FOR ONE GAME_ID ####
# Once I'm finished caching, I will loop through all the cached {game_id}.xml files

# Initialize an empty dictionary to store the data
data_dict = {}

# Find all 'poll' tags
polls = soup.find_all("poll")

# Iterate over 'poll' tags
for poll in polls:
    poll_name = poll.get('name', 'N/A')
    print(poll_name)

    # Find all 'results' tags within the current poll
    results_tags_hier1_all = poll.find_all("results")

    # Iterate over 'results' tags within the results (within the current poll)
    for results_tag_hier1 in results_tags_hier1_all:
        num_players = results_tag_hier1.get('numplayers', 'N/A')

        # Find all 'result' tags within the current 'results' tag
        results_tags_hier2_all = results_tag_hier1.find_all('result')

        # Iterate over 'result' tags
        for results_tag_hier2 in results_tags_hier2_all:
            num_votes = results_tag_hier2.get('numvotes', 'N/A')
            value = results_tag_hier2.get('value', 'N/A')

            # Determine the appropriate column name based on the poll name
            if poll_name == 'suggested_numplayers':
                if value == 'Not Recommended':
                    value = "NR"
                    column_name = f"{num_players}_{value}"
                elif value == 'Recommended':
                    value = "Rec"
                    column_name = f"{num_players}_{value}"
                else:
                    column_name = f"{num_players}_{value}"
            elif poll_name == 'suggested_playerage':
                column_name = f"{value}_Yrs"
            elif poll_name == 'language_dependence':
                level = results_tag_hier2.get('level', 'N/A')
                column_name = f"Lang_{level}"
            else:
                column_name = f"{poll_name}_{num_players}_{value}"

            # Store the data in the dictionary
            data_dict["game_id"] = game_id
            data_dict[column_name] = num_votes

# Create a DataFrame from the data dictionary
df = pd.DataFrame([data_dict])
df
# Out:
# suggested_numplayers
# suggested_playerage
# language_dependence
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7944\1253032821.py in <module>
#      52 # Create a DataFrame from the data dictionary
#      53 df = pd.DataFrame([data_dict])
# ---> 54 df[1]
#      55
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 1

# %%
# SQL Code to create table based on each of the column names
# For games_polls

# Connect to the SQLite database
# con = sqlite3.connect('your_database.db')
# cur = con.cursor()

# Assuming 'df' is your DataFrame
column_names = df.columns.tolist()

table_name = 'games_polls'

# Generate the CREATE TABLE statement
create_table_sql = f"CREATE TABLE {table_name} ("
for column_name in column_names:
    create_table_sql += f"{column_name} TEXT,"
create_table_sql = create_table_sql.rstrip(',')  # Remove the trailing comma
create_table_sql += ")"

# Execute the CREATE TABLE statement
cur.execute(create_table_sql)

# Commit the changes and close the connection
con.commit()
con.close()

# %%
# Extract all ratings data
#<usersrated value="5661"/>
#    <average value="7.59864"/>
#    <bayesaverage value="7.0577"/>
#    <ranks>
#     <rank bayesaverage="7.0577" friendlyname="Board Game Rank" id="1" name="boardgame" type="subtype" value="384"/>
#     <rank bayesaverage="7.19178" friendlyname="Strategy Game Rank" id="5497" name="strategygames" type="family" value="221"/>
#    </ranks>
#    <stddev value="1.57457"/>
#    <median value="0"/>
#    <owned value="7973"/>
#    <trading value="258"/>
#    <wanting value="507"/>
#    <wishing value="2119"/>
#    <numcomments value="2065"/>
#    <numweights value="777"/>
#    <averageweight value="4.3153"/>

# Initialize an empty dictionary
ratings_dict = []

ranks = soup.find_all("ranks")
ratings = soup.find_all("ratings")

for rank in ranks:
    try:
        if rank.get('friendlyname') == "Board Game Rank":
            bgg_rank_info = rank.find('bayesaverage')
            print(bgg_rank_info)
            bgg_rank_id_info = rank.find('id')
            bgg_rank_name_info = rank.find('name')
            bgg_rank_type_info = rank.find('type')
            bgg_rank_value_info = rank.find('value')
        if rank.get('friendlyname') == "Strategy Game Rank":
            sgg_rank_info = rank.find('bayesaverage')
            sgg_rank_id_info = rank.find('id')
            sgg_rank_name_info = rank.find('name')
            sgg_rank_type_info = rank.find('type')
            sgg_rank_value_info = rank.find('value')
  
    except AttributeError:
        print(f"There was an AttributeError: {AttributeError}")
        continue # Skip to next iteration
    try:
        bgg_rank = bgg_rank_info.get('bayesaverage')
        bgg_rank_id = bgg_rank_id_info.get('id')
        bgg_rank_name = bgg_rank_name_info.get('name')
        bgg_rank_type = bgg_rank_type_info.get('type')
        bgg_rank_value = bgg_rank_value_info.get('value')
        sgg_rank = sgg_rank_info.get('bayesaverage')
        sgg_rank_id = sgg_rank_id_info.get('id')
        sgg_rank_name = sgg_rank_name_info.get('name')
        sgg_rank_type = sgg_rank_type_info.get('type')
        sgg_rank_value = sgg_rank_value_info.get('value')
    
    except ValueError as e:
        print(f"ValueError for game id: {game_id}")
        continue # Skip to next iteration
    
    ratings_dict.append([bgg_rank,bgg_rank_id,bgg_rank_name,bgg_rank_type,bgg_rank_value,
                         sgg_rank,sgg_rank_id,sgg_rank_name,sgg_rank_type,sgg_rank_value])
        

for rating in ratings:
    try:
        # Get the main info on a game from search_url
        avg_info = rating.find("average")
        bayes_avg_info = rating.find("bayesaverage")
        stddev_info = rating.find("stddev")
        median_info = rating.find("median")
        owned_info = rating.find("owned")
        trading_info = rating.find("trading")
        wanting_info = rating.find("wanting")
        wishing_info = rating.find("wishing")
        num_comments_info = rating.find("numcomments")
        num_weights_info = rating.find("numweights")
        avg_weight_info = rating.find("averageweight")
    except AttributeError:
        print(f"There was an AttributeError: {AttributeError}")
        continue # Skip to next iteration
    
        
    # Extract single values for a given game id
    try:
        avg = avg_info.get('value') if release_year_info else 'N/A'
        bayesavg = bayes_avg_info.get('value') if bayes_avg_info else 'N/A'
        stddev = stddev_info.get('value') if stddev_info else 'N/A'
        median= median_info.get('value') if median_info else 'N/A'
        owned = owned_info.get('value') if owned_info else 'N/A'
        trading = trading_info.get('value') if trading_info else 'N/A'
        wanting = wanting_info.get('value') if wanting_info else 'N/A'
        wishing = wishing_info.get('value') if wishing_info else 'N/A'
        numcomments = num_comments_info.get('value') if num_comments_info else 'N/A'
        numweights = num_weights_info.get('value') if num_weights_info else 'N/A'
        avgweight = avg_weight_info.get('value') if avg_weight_info else 'N/A'

    except ValueError as e:
        print(f"ValueError for game id: {game_id}")
        continue # Skip to next iteration
    
    
    ratings_dict.append([avg,bayesavg,stddev,median,owned,trading,wanting,wishing,numcomments,numweights,avgweight])
    # print(f"Appended data for game id: {game_id}")  # Debug print

print("Completed loop.")  # Debug print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7944\832567850.py in <module>
#      43         continue # Skip to next iteration
#      44     try:
# ---> 45         bgg_rank = bgg_rank_info.get('bayesaverage')
#      46         bgg_rank_id = bgg_rank_id_info.get('id')
#      47         bgg_rank_name = bgg_rank_name_info.get('name')
#
# NameError: name 'bgg_rank_info' is not defined

# %%
# Initialize an empty dictionary
ratings_dict = {}

# Extract rankings data
ranks = soup.find_all("rank")
for rank in ranks:
    friendlyname = rank.get("friendlyname")
    bayesaverage = rank.get("bayesaverage")
    rank_id = rank.get("id")
    rank_name = rank.get("name")
    rank_type = rank.get("type")
    rank_value = rank.get("value")
    if friendlyname and bayesaverage and rank_id and rank_name and rank_type and rank_value:
        key = f"{friendlyname}_{rank_id}"
        abbrev_friendlyname = ""
        if friendlyname == "Board Game Rank":
            abbrev_friendlyname = "bgg"
        elif friendlyname == "Strategy Game Rank":
            abbrev_friendlyname = "sgg"

        ratings_dict.setdefault(f"{abbrev_friendlyname}_bayesaverage", []).append(bayesaverage)
        ratings_dict.setdefault(f"{abbrev_friendlyname}_id", []).append(rank_id)
        ratings_dict.setdefault(f"{abbrev_friendlyname}_name", []).append(rank_name)
        ratings_dict.setdefault(f"{abbrev_friendlyname}_type", []).append(rank_type)
        ratings_dict.setdefault(f"{abbrev_friendlyname}_value", []).append(rank_value)


# Extract ratings data
ratings = soup.find("ratings")
if ratings:
    for rating in ratings.children:
        if rating.name is not None:
            value = rating.get("value")
            if value:
                ratings_dict[rating.name] = value

print(ratings_dict)
# Out:
# {'bgg_bayesaverage': ['7.0577'], 'bgg_id': ['1'], 'bgg_name': ['boardgame'], 'bgg_type': ['subtype'], 'bgg_value': ['384'], 'sgg_bayesaverage': ['7.19178'], 'sgg_id': ['5497'], 'sgg_name': ['strategygames'], 'sgg_type': ['family'], 'sgg_value': ['221'], 'usersrated': '5661', 'average': '7.59864', 'bayesaverage': '7.0577', 'stddev': '1.57457', 'median': '0', 'owned': '7973', 'trading': '258', 'wanting': '507', 'wishing': '2119', 'numcomments': '2065', 'numweights': '777', 'averageweight': '4.3153'}

# %%
df_ratingsranks = pd.DataFrame(ratings_dict)
df_ratingsranks
# Out:
#   bgg_bayesaverage bgg_id   bgg_name bgg_type bgg_value sgg_bayesaverage  \
# 0           7.0577      1  boardgame  subtype       384          7.19178
#
#   sgg_id       sgg_name sgg_type sgg_value  ... bayesaverage   stddev median  \
# 0   5497  strategygames   family       221  ...       7.0577  1.57457      0
#
#   owned trading wanting wishing numcomments numweights averageweight
# 0  7973     258     507    2119        2065        777        4.3153
#
# [1 rows x 22 columns]

# %%
# Define the table name
table_name = 'ratings_data'

# Insert the DataFrame into the SQL table
df.to_sql(table_name, con, if_exists='replace', index=False)

# Close the database connection
con.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7944\167532143.py in <module>
#       3
#       4 # Insert the DataFrame into the SQL table
# ----> 5 df.to_sql(table_name, con, if_exists='replace', index=False)
#       6
#       7 # Close the database connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2191         )
#    2192         table.create()
# -> 2193         return table.insert(chunksize, method)
#    2194
#    2195     def has_table(self, name: str, schema: str | None = None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     949
#     950                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 951                 num_inserted = exec_insert(conn, keys, chunk_iter)
#     952                 # GH 46891
#     953                 if is_integer(num_inserted):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#    1897     def _execute_insert(self, conn, keys, data_iter) -> int:
#    1898         data_list = list(data_iter)
# -> 1899         conn.executemany(self.insert_statement(num_rows=1), data_list)
#    1900         return conn.rowcount
#    1901
#
# InterfaceError: Error binding parameter 0 - probably unsupported type.

# %%
# Extract categorical infomration such as boardgamecategory, boardgamemechanic, boardgame family, boardgame designer, boardgame publisher

# Initialize an empty dictionary and counter for each type
data_dict = {}
type_counter = {}

# Extract id, type, and value attributes from XML snippet
links = soup.find_all("link")
for link in links:
    type_name = link["type"]
    value = link["value"]
    if type_name not in type_counter:
        type_counter[type_name] = 1
    else:
        type_counter[type_name] += 1
    column_name = f"{type_name}{type_counter[type_name]}"
    data_dict[column_name] = value

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(data_dict, orient="index").T

df
# Out:
#   boardgamecategory1 boardgamecategory2 boardgamecategory3 boardgamemechanic1  \
# 0           Economic        Negotiation          Political          Alliances
#
#           boardgamemechanic2 boardgamemechanic3 boardgamemechanic4  \
# 0  Area Majority / Influence    Auction/Bidding       Dice Rolling
#
#   boardgamemechanic5             boardgamemechanic6  boardgamefamily1  ...  \
# 0    Hand Management  Simultaneous Action Selection  Country: Germany  ...
#
#   boardgameartist2 boardgamepublisher1 boardgamepublisher2  \
# 0    Harald Lieske       Hans im Glück      Moskito Spiele
#
#    boardgamepublisher3 boardgamepublisher4 boardgamepublisher5  \
# 0  Ediciones MasQueOca        Portal Games          Spielworxx
#
#    boardgamepublisher6 boardgamepublisher7 boardgamepublisher8  \
# 0  sternenschimmermeer    Stronghold Games  Valley Games, Inc.
#
#   boardgamepublisher9
# 0          YOKA Games
#
# [1 rows x 24 columns]
